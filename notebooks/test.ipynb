# %%
import pandas as pd

df = pd.read_csv('../data/wine_samples.csv')
df
# Out:
#    fixed_acidity;volatile_acidity;citric_acid;residual_sugar;chlorides;free_sulfur_dioxide;total_sulfur_dioxide;density;pH;sulphates;alcohol;class
# 0   7.7;0.56;0.08;2.5;0.114;14.0;46.0;0.9971;3.24;...
# 1   7.8;0.5;0.17;1.6;0.082;21.0;102.0;0.996;3.39;0...
# 2   10.7;0.67;0.22;2.7;0.107;17.0;34.0;1.0004;3.28...
# 3   8.5;0.46;0.31;2.25;0.078;32.0;58.0;0.998;3.33;...
# 4   6.7;0.46;0.24;1.7;0.077;18.0;34.0;0.9948;3.39;...
# 5   7.2;0.41;0.3;2.1;0.083;35.0;72.0;0.997;3.44;0....
# 6   7.7;0.54;0.26;1.9;0.089;23.0;147.0;0.99636;3.2...
# 7   7.0;0.78;0.08;2.0;0.093;10.0;19.0;0.9956;3.4;0...
# 8   8.2;0.39;0.38;1.5;0.058;10.0;29.0;0.9962;3.26;...
# 9   5.8;0.61;0.11;1.8;0.066;18.0;28.0;0.99483;3.55...
# 10  10.5;0.51;0.64;2.4;0.107;6.0;15.0;0.9973;3.09;...
# 11  6.7;0.76;0.02;1.8;0.078;6.0;12.0;0.996;3.55;0....
# 12  6.7;0.48;0.08;2.1;0.064;18.0;34.0;0.99552;3.33...
# 13  7.0;0.56;0.13;1.6;0.077;25.0;42.0;0.99629;3.34...
# 14  7.8;0.34;0.37;2.0;0.082;24.0;58.0;0.9964;3.34;...
# ...
